# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import json
import re
import matplotlib.pyplot as plt

# %%
plot_metrics = ['hellaswag', 'lambada_openai', 'lambada_standard', 'piqa', 'truthfulqa_mc2', 'winogrande', 'arc_challenge', 'gsm8k', 'medmcqa', 'mmlu', 'paloma_wikitext_103', ]

metric_keys = [
    'acc_norm,none',
    'acc,none',
    'exact_match,strict-match',
    'exact_match,flexible-extract',
    'perplexity,none',
    'word_perplexity,none'
]

def extract_number_from_filename(filename):
    """Extract the number from filename like 'lm_eval_begin_0.json' or 'lm_eval_interval_1221.json'"""
    # Remove .json extension and split by underscore
    name_without_ext = filename.replace('.json', '')
    parts = name_without_ext.split('_')
    # The number is always the last part
    return int(parts[-1].replace('step', ''))

# %%
res_path = "./results/midtrain_allenai"
output_csv = './results_data.csv'
output_dir = "./figures"
os.makedirs(output_dir, exist_ok=True)

# %%
res_folders = os.listdir(res_path)
result_list = []
for res_folder in res_folders:
    disp_setting = re.search(r'disp-([^-]+-[^-]+)', res_folder).group(1)
    files = sorted([f for f in os.listdir(os.path.join(res_path, res_folder)) if f.startswith('lm_eval_')])
    print(f"{res_folder}")
    for file in files:
        print(f"{file}")
        step = extract_number_from_filename(file)
        with open(f'{res_path}/{res_folder}/{file}', 'r') as f:
            data = json.load(f)

        result = {}

        result['filename'] = file
        result['step'] = step
        result['disp'] = disp_setting
        
        for plot_metric in plot_metrics:
            res = data['results'][plot_metric]
            key_used = None
            for key in metric_keys:
                if key in res.keys():
                    key_used = key
                    break
            assert key_used is not None, 'no key found'
            result_value = res[key_used]
            result_key = plot_metric + ',' + key_used
            result[result_key] = result_value

        result_list.append(result)

df = pd.DataFrame(result_list).sort_values('step')
df.to_csv(output_csv, index=False)
# Out:
# OLMo-2-0425-1B_DKYoon-SlimPajama-6B_lr-1e-06_token-1600000000_disp-covariance-0.5-all_fewshot-1_maxsample-200_seed-1
# lm_eval_begin_0.json
# lm_eval_interval_10989.json
# lm_eval_interval_1221.json
# lm_eval_interval_2442.json
# lm_eval_interval_3663.json
# lm_eval_interval_4884.json
# lm_eval_interval_6105.json
# lm_eval_interval_7326.json
# lm_eval_interval_8547.json
# lm_eval_interval_9768.json
# OLMo-2-0425-1B_DKYoon-SlimPajama-6B_lr-1e-06_token-1600000000_disp-infonce_l2-0.5-all_fewshot-1_maxsample-200_seed-1
# lm_eval_begin_0.json
# lm_eval_interval_10989.json
# lm_eval_interval_1221.json
# lm_eval_interval_2442.json
# lm_eval_interval_3663.json
# lm_eval_interval_4884.json
# lm_eval_interval_6105.json
# lm_eval_interval_7326.json
# lm_eval_interval_8547.json
# lm_eval_interval_9768.json
# OLMo-2-0425-1B_DKYoon-SlimPajama-6B_lr-1e-06_token-1600000000_disp-hinge-0.5-all_fewshot-1_maxsample-200_seed-1
# lm_eval_begin_0.json
# lm_eval_interval_10989.json
# lm_eval_interval_1221.json
# lm_eval_interval_2442.json
# lm_eval_interval_3663.json
# lm_eval_interval_4884.json
# lm_eval_interval_6105.json
# lm_eval_interval_7326.json
# lm_eval_interval_8547.json
# lm_eval_interval_9768.json
# OLMo-2-0425-1B_DKYoon-SlimPajama-6B_lr-1e-06_token-1600000000_disp-infonce_cosine-0.5-all_fewshot-1_maxsample-200_seed-1
# lm_eval_begin_0.json
# lm_eval_interval_10989.json
# lm_eval_interval_1221.json
# lm_eval_interval_2442.json
# lm_eval_interval_3663.json
# lm_eval_interval_4884.json
# lm_eval_interval_6105.json
# lm_eval_interval_7326.json
# lm_eval_interval_8547.json
# lm_eval_interval_9768.json
# OLMo-2-0425-1B_DKYoon-SlimPajama-6B_lr-1e-06_token-1600000000_disp-None-1-last_fewshot-1_maxsample-200_seed-1
# lm_eval_begin_0.json
# lm_eval_end_12208.json
# lm_eval_interval_10989.json
# lm_eval_interval_1221.json
# lm_eval_interval_2442.json
# lm_eval_interval_3663.json
# lm_eval_interval_4884.json
# lm_eval_interval_6105.json
# lm_eval_interval_7326.json
# lm_eval_interval_8547.json
# lm_eval_interval_9768.json

# %%
df
# Out:
#                        filename   step                disp  \
# 0          lm_eval_begin_0.json      0      covariance-0.5
# 10         lm_eval_begin_0.json      0      infonce_l2-0.5
# 30         lm_eval_begin_0.json      0  infonce_cosine-0.5
# 20         lm_eval_begin_0.json      0           hinge-0.5
# 40         lm_eval_begin_0.json      0              None-1
# 12   lm_eval_interval_1221.json   1221      infonce_l2-0.5
# 2    lm_eval_interval_1221.json   1221      covariance-0.5
# 22   lm_eval_interval_1221.json   1221           hinge-0.5
# 32   lm_eval_interval_1221.json   1221  infonce_cosine-0.5
# 43   lm_eval_interval_1221.json   1221              None-1
# 23   lm_eval_interval_2442.json   2442           hinge-0.5
# 44   lm_eval_interval_2442.json   2442              None-1
# 33   lm_eval_interval_2442.json   2442  infonce_cosine-0.5
# 13   lm_eval_interval_2442.json   2442      infonce_l2-0.5
# 3    lm_eval_interval_2442.json   2442      covariance-0.5
# 14   lm_eval_interval_3663.json   3663      infonce_l2-0.5
# 4    lm_eval_interval_3663.json   3663      covariance-0.5
# 34   lm_eval_interval_3663.json   3663  infonce_cosine-0.5
# 45   lm_eval_interval_3663.json   3663              None-1
# 24   lm_eval_interval_3663.json   3663           hinge-0.5
# 35   lm_eval_interval_4884.json   4884  infonce_cosine-0.5
# 15   lm_eval_interval_4884.json   4884      infonce_l2-0.5
# 25   lm_eval_interval_4884.json   4884           hinge-0.5
# 46   lm_eval_interval_4884.json   4884              None-1
# 5    lm_eval_interval_4884.json   4884      covariance-0.5
# 26   lm_eval_interval_6105.json   6105           hinge-0.5
# 16   lm_eval_interval_6105.json   6105      infonce_l2-0.5
# 6    lm_eval_interval_6105.json   6105      covariance-0.5
# 47   lm_eval_interval_6105.json   6105              None-1
# 36   lm_eval_interval_6105.json   6105  infonce_cosine-0.5
# 7    lm_eval_interval_7326.json   7326      covariance-0.5
# 27   lm_eval_interval_7326.json   7326           hinge-0.5
# 48   lm_eval_interval_7326.json   7326              None-1
# 37   lm_eval_interval_7326.json   7326  infonce_cosine-0.5
# 17   lm_eval_interval_7326.json   7326      infonce_l2-0.5
# 18   lm_eval_interval_8547.json   8547      infonce_l2-0.5
# 8    lm_eval_interval_8547.json   8547      covariance-0.5
# 38   lm_eval_interval_8547.json   8547  infonce_cosine-0.5
# 49   lm_eval_interval_8547.json   8547              None-1
# 28   lm_eval_interval_8547.json   8547           hinge-0.5
# 50   lm_eval_interval_9768.json   9768              None-1
# 9    lm_eval_interval_9768.json   9768      covariance-0.5
# 29   lm_eval_interval_9768.json   9768           hinge-0.5
# 39   lm_eval_interval_9768.json   9768  infonce_cosine-0.5
# 19   lm_eval_interval_9768.json   9768      infonce_l2-0.5
# 21  lm_eval_interval_10989.json  10989           hinge-0.5
# 1   lm_eval_interval_10989.json  10989      covariance-0.5
# 11  lm_eval_interval_10989.json  10989      infonce_l2-0.5
# 31  lm_eval_interval_10989.json  10989  infonce_cosine-0.5
# 42  lm_eval_interval_10989.json  10989              None-1
# 41       lm_eval_end_12208.json  12208              None-1
#
#     hellaswag,acc_norm,none  lambada_openai,acc,none  \
# 0                     0.630                    0.660
# 10                    0.630                    0.660
# 30                    0.630                    0.660
# 20                    0.630                    0.660
# 40                    0.630                    0.660
# 12                    0.635                    0.630
# 2                     0.630                    0.640
# 22                    0.625                    0.635
# 32                    0.635                    0.635
# 43                    0.630                    0.640
# 23                    0.635                    0.635
# 44                    0.635                    0.635
# 33                    0.635                    0.630
# 13                    0.635                    0.630
# 3                     0.630                    0.630
# 14                    0.640                    0.610
# 4                     0.635                    0.630
# 34                    0.635                    0.630
# 45                    0.630                    0.645
# 24                    0.630                    0.645
# 35                    0.630                    0.640
# 15                    0.640                    0.625
# 25                    0.630                    0.640
# 46                    0.630                    0.645
# 5                     0.630                    0.625
# 26                    0.630                    0.640
# 16                    0.640                    0.625
# 6                     0.630                    0.620
# 47                    0.625                    0.650
# 36                    0.635                    0.635
# 7                     0.640                    0.620
# 27                    0.630                    0.650
# 48                    0.630                    0.645
# 37                    0.630                    0.630
# 17                    0.640                    0.615
# 18                    0.640                    0.610
# 8                     0.640                    0.620
# 38                    0.635                    0.620
# 49                    0.635                    0.650
# 28                    0.630                    0.645
# 50                    0.630                    0.650
# 9                     0.640                    0.620
# 29                    0.630                    0.650
# 39                    0.635                    0.625
# 19                    0.640                    0.615
# 21                    0.630                    0.650
# 1                     0.640                    0.625
# 11                    0.640                    0.615
# 31                    0.630                    0.625
# 42                    0.630                    0.645
# 41                    0.630                    0.655
#
#     lambada_standard,acc,none  piqa,acc_norm,none  truthfulqa_mc2,acc,none  \
# 0                       0.575               0.770                 0.388765
# 10                      0.575               0.770                 0.388765
# 30                      0.575               0.770                 0.388765
# 20                      0.575               0.770                 0.388765
# 40                      0.575               0.770                 0.388765
# 12                      0.555               0.775                 0.406149
# 2                       0.565               0.780                 0.403989
# 22                      0.555               0.780                 0.404037
# 32                      0.560               0.775                 0.403720
# 43                      0.560               0.775                 0.403220
# 23                      0.560               0.775                 0.406485
# 44                      0.560               0.760                 0.408007
# 33                      0.550               0.760                 0.406651
# 13                      0.535               0.760                 0.408994
# 3                       0.560               0.760                 0.407097
# 14                      0.535               0.765                 0.407331
# 4                       0.560               0.765                 0.406912
# 34                      0.560               0.760                 0.407958
# 45                      0.560               0.760                 0.410314
# 24                      0.560               0.760                 0.408957
# 35                      0.560               0.760                 0.406603
# 15                      0.520               0.750                 0.405602
# 25                      0.555               0.765                 0.407967
# 46                      0.550               0.745                 0.409007
# 5                       0.555               0.765                 0.404725
# 26                      0.555               0.755                 0.407565
# 16                      0.510               0.750                 0.406307
# 6                       0.555               0.760                 0.404325
# 47                      0.570               0.750                 0.408280
# 36                      0.560               0.765                 0.406004
# 7                       0.555               0.760                 0.403681
# 27                      0.575               0.770                 0.407693
# 48                      0.555               0.750                 0.407247
# 37                      0.555               0.765                 0.404092
# 17                      0.495               0.745                 0.404669
# 18                      0.490               0.750                 0.403732
# 8                       0.560               0.760                 0.403371
# 38                      0.550               0.760                 0.405032
# 49                      0.550               0.760                 0.407878
# 28                      0.555               0.760                 0.406786
# 50                      0.555               0.745                 0.408362
# 9                       0.555               0.755                 0.402609
# 29                      0.555               0.755                 0.406026
# 39                      0.550               0.760                 0.404559
# 19                      0.510               0.760                 0.403431
# 21                      0.550               0.765                 0.407220
# 1                       0.555               0.760                 0.402681
# 11                      0.485               0.745                 0.403454
# 31                      0.555               0.760                 0.404650
# 42                      0.550               0.755                 0.408453
# 41                      0.555               0.750                 0.407909
#
#     winogrande,acc,none  arc_challenge,acc_norm,none  \
# 0                 0.700                        0.410
# 10                0.700                        0.410
# 30                0.700                        0.410
# 20                0.700                        0.410
# 40                0.700                        0.410
# 12                0.670                        0.400
# 2                 0.695                        0.385
# 22                0.715                        0.395
# 32                0.700                        0.390
# 43                0.705                        0.400
# 23                0.700                        0.395
# 44                0.700                        0.405
# 33                0.700                        0.400
# 13                0.690                        0.400
# 3                 0.715                        0.400
# 14                0.685                        0.395
# 4                 0.690                        0.390
# 34                0.695                        0.395
# 45                0.695                        0.400
# 24                0.705                        0.395
# 35                0.690                        0.385
# 15                0.690                        0.400
# 25                0.705                        0.390
# 46                0.695                        0.400
# 5                 0.680                        0.395
# 26                0.705                        0.400
# 16                0.695                        0.380
# 6                 0.695                        0.390
# 47                0.705                        0.400
# 36                0.705                        0.395
# 7                 0.680                        0.395
# 27                0.695                        0.400
# 48                0.700                        0.405
# 37                0.695                        0.405
# 17                0.695                        0.385
# 18                0.700                        0.380
# 8                 0.685                        0.395
# 38                0.700                        0.400
# 49                0.690                        0.405
# 28                0.690                        0.400
# 50                0.690                        0.405
# 9                 0.715                        0.395
# 29                0.705                        0.395
# 39                0.690                        0.395
# 19                0.700                        0.380
# 21                0.680                        0.395
# 1                 0.690                        0.395
# 11                0.700                        0.385
# 31                0.685                        0.395
# 42                0.685                        0.400
# 41                0.690                        0.405
#
#     gsm8k,exact_match,strict-match  medmcqa,acc_norm,none  mmlu,acc,none  \
# 0                            0.305                  0.285       0.426440
# 10                           0.305                  0.285       0.426440
# 30                           0.305                  0.285       0.426440
# 20                           0.305                  0.285       0.426440
# 40                           0.305                  0.285       0.426440
# 12                           0.215                  0.320       0.424153
# 2                            0.230                  0.305       0.428074
# 22                           0.270                  0.305       0.425787
# 32                           0.235                  0.310       0.427311
# 43                           0.270                  0.300       0.428291
# 23                           0.270                  0.290       0.427094
# 44                           0.280                  0.290       0.424480
# 33                           0.260                  0.310       0.427638
# 13                           0.200                  0.355       0.416639
# 3                            0.235                  0.315       0.427747
# 14                           0.200                  0.355       0.404987
# 4                            0.210                  0.315       0.426767
# 34                           0.225                  0.310       0.429707
# 45                           0.280                  0.300       0.426113
# 24                           0.260                  0.305       0.424807
# 35                           0.225                  0.310       0.426876
# 15                           0.195                  0.320       0.395078
# 25                           0.255                  0.300       0.426549
# 46                           0.260                  0.290       0.425787
# 5                            0.195                  0.310       0.424916
# 26                           0.260                  0.290       0.424262
# 16                           0.200                  0.310       0.387019
# 6                            0.200                  0.315       0.425569
# 47                           0.255                  0.295       0.425133
# 36                           0.210                  0.310       0.425460
# 7                            0.200                  0.310       0.426440
# 27                           0.260                  0.285       0.426876
# 48                           0.250                  0.275       0.425025
# 37                           0.215                  0.320       0.427529
# 17                           0.190                  0.305       0.383644
# 18                           0.200                  0.310       0.382119
# 8                            0.190                  0.315       0.426222
# 38                           0.205                  0.320       0.425896
# 49                           0.245                  0.265       0.425896
# 28                           0.240                  0.305       0.426331
# 50                           0.255                  0.275       0.424371
# 9                            0.205                  0.315       0.426331
# 29                           0.250                  0.300       0.425569
# 39                           0.220                  0.315       0.426767
# 19                           0.190                  0.305       0.378417
# 21                           0.235                  0.295       0.427202
# 1                            0.205                  0.315       0.425787
# 11                           0.205                  0.310       0.378634
# 31                           0.225                  0.330       0.427856
# 42                           0.230                  0.295       0.424371
# 41                           0.250                  0.280       0.426985
#
#     paloma_wikitext_103,word_perplexity,none
# 0                                  12.855828
# 10                                 12.855828
# 30                                 12.855828
# 20                                 12.855828
# 40                                 12.855828
# 12                                 13.116436
# 2                                  12.846022
# 22                                 12.834874
# 32                                 12.825515
# 43                                 12.847210
# 23                                 12.878061
# 44                                 12.878819
# 33                                 12.881987
# 13                                 13.336412
# 3                                  12.906545
# 14                                 13.480044
# 4                                  12.946489
# 34                                 12.909122
# 45                                 12.900279
# 24                                 12.896781
# 35                                 12.929545
# 15                                 13.563612
# 25                                 12.906762
# 46                                 12.913465
# 5                                  12.978179
# 26                                 12.926175
# 16                                 13.636771
# 6                                  12.983254
# 47                                 12.924029
# 36                                 12.937484
# 7                                  12.990434
# 27                                 12.927099
# 48                                 12.931774
# 37                                 12.945700
# 17                                 13.691749
# 18                                 13.719493
# 8                                  12.993301
# 38                                 12.954629
# 49                                 12.936342
# 28                                 12.927045
# 50                                 12.941972
# 9                                  12.995951
# 29                                 12.933188
# 39                                 12.956399
# 19                                 13.733776
# 21                                 12.933160
# 1                                  12.994831
# 11                                 13.737934
# 31                                 12.953104
# 42                                 12.933731
# 41                                 12.934166

# %%
# Get unique dispersion methods (excluding None-1)
disp_methods = [d for d in df['disp'].unique() if d != 'None-1']
# Get metric columns (excluding filename, step, disp)
metric_cols = [col for col in df.columns if col not in ['filename', 'step', 'disp']]

# Create subplots
fig, axes = plt.subplots(len(disp_methods), len(metric_cols), 
                        figsize=(4*len(metric_cols), 3*len(disp_methods)))

# Ensure axes is 2D array
if len(disp_methods) == 1:
    axes = axes.reshape(1, -1)
if len(metric_cols) == 1:
    axes = axes.reshape(-1, 1)

# Get baseline data (None-1)
baseline_data = df[df['disp'] == 'None-1']

# Plot for each dispersion method and metric
for i, disp in enumerate(disp_methods):
    for j, metric in enumerate(metric_cols):
        ax = axes[i, j]
        
        # Plot baseline (None-1) as gray dashed line
        if not baseline_data.empty:
            ax.plot(baseline_data['step'], baseline_data[metric], 
                   color='gray', linestyle='--', alpha=0.7, label='None-1')
        
        # Plot current dispersion method
        method_data = df[df['disp'] == disp]
        if not method_data.empty:
            ax.plot(method_data['step'], method_data[metric], 
                   marker='o', label=disp)
        
        # Set labels and title
        ax.set_xlabel('Step')
        ax.set_ylabel(metric)
        ax.legend()
        ax.grid(True, alpha=0.3)
        
        # Add column labels on top row
        if i == 0:
            ax.set_title(metric, fontsize=12, fontweight='bold')
    
    # Add row labels on left column
    if len(metric_cols) > 0:
        axes[i, 0].set_ylabel(f'{disp}\n{metric_cols[0]}', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
df[df['step'] == 0]#[['arc_challenge,acc_norm,none']]
# Out:
#                              filename  step                disp  \
# 0  lm_eval_eval_ckpt_begin_step0.json     0              None-1
# 2  lm_eval_eval_ckpt_begin_step0.json     0  infonce_cosine-0.5
# 6  lm_eval_eval_ckpt_begin_step0.json     0           hinge-0.5
# 4  lm_eval_eval_ckpt_begin_step0.json     0      covariance-0.5
# 8  lm_eval_eval_ckpt_begin_step0.json     0      infonce_l2-0.5
#
#    hellaswag,acc_norm,none  lambada_openai,acc,none  \
# 0                     0.58                     0.62
# 2                     0.58                     0.62
# 6                     0.58                     0.62
# 4                     0.58                     0.62
# 8                     0.58                     0.62
#
#    lambada_standard,acc,none  piqa,acc_norm,none  truthfulqa_mc2,acc,none  \
# 0                      0.565                0.74                 0.391939
# 2                      0.565                0.74                 0.391939
# 6                      0.565                0.74                 0.391939
# 4                      0.565                0.74                 0.391939
# 8                      0.565                0.74                 0.391939
#
#    winogrande,acc,none  arc_challenge,acc_norm,none  \
# 0                0.575                        0.365
# 2                0.575                        0.365
# 6                0.575                        0.365
# 4                0.575                        0.365
# 8                0.575                        0.325
#
#    gsm8k,exact_match,strict-match  medmcqa,acc_norm,none  mmlu,acc,none  \
# 0                           0.025                  0.395       0.326037
# 2                           0.025                  0.395       0.326037
# 6                           0.025                  0.395       0.326037
# 4                           0.025                  0.395       0.326037
# 8                           0.035                  0.310       0.326255
#
#    paloma_wikitext_103,word_perplexity,none
# 0                                 12.631878
# 2                                 12.631878
# 6                                 12.631878
# 4                                 12.631878
# 8                                 12.631878

# %%
step_col = 'step'
to_plot_cols = [f for f in df.columns if f not in ['filename', 'step']]
methods =
# Out:
#   Cell In[11], line 3
#     methods =
#               ^
# SyntaxError: invalid syntax

# %%
# Out:
# ['hellaswag,acc_norm,none',
#  'lambada_openai,acc,none',
#  'lambada_standard,acc,none',
#  'piqa,acc_norm,none',
#  'truthfulqa_mc2,acc,none',
#  'winogrande,acc,none',
#  'arc_challenge,acc_norm,none',
#  'gsm8k,exact_match,strict-match',
#  'medmcqa,acc_norm,none',
#  'mmlu,acc,none',
#  'paloma_wikitext_103,word_perplexity,none']

# %%
data
# Out:
# {'results': {'hellaswag': {'alias': 'hellaswag',
#    'acc,none': 0.475,
#    'acc_stderr,none': 0.0353997274497642,
#    'acc_norm,none': 0.565,
#    'acc_norm_stderr,none': 0.03514328173714407},
#   'lambada_openai': {'alias': 'lambada_openai',
#    'perplexity,none': 5.613191204849795,
#    'perplexity_stderr,none': 0.7023954075033207,
#    'acc,none': 0.625,
#    'acc_stderr,none': 0.03431856376795913},
#   'lambada_standard': {'alias': 'lambada_standard',
#    'perplexity,none': 7.622786948217177,
#    'perplexity_stderr,none': 1.031526615817041,
#    'acc,none': 0.555,
#    'acc_stderr,none': 0.0352289710609046},
#   'paloma_wikitext_103': {'alias': 'Wikitext-103',
#    'word_perplexity,none': 12.827861271186743,
#    'word_perplexity_stderr,none': 'N/A',
#    'byte_perplexity,none': 1.6110388714562571,
#    'byte_perplexity_stderr,none': 'N/A',
#    'bits_per_byte,none': 0.687991304088317,
#    'bits_per_byte_stderr,none': 'N/A'},
#   'piqa': {'alias': 'piqa',
#    'acc,none': 0.74,
#    'acc_stderr,none': 0.031093957143700272,
#    'acc_norm,none': 0.755,
#    'acc_norm_stderr,none': 0.030488073292114216},
#   'truthfulqa_mc2': {'alias': 'truthfulqa_mc2',
#    'acc,none': 0.3973875926952548,
#    'acc_stderr,none': 0.027500393598615565},
#   'winogrande': {'alias': 'winogrande',
#    'acc,none': 0.58,
#    'acc_stderr,none': 0.0349874349304872},
#   'arc_challenge': {'alias': 'arc_challenge',
#    'acc,none': 0.3,
#    'acc_stderr,none': 0.03248501780682213,
#    'acc_norm,none': 0.335,
#    'acc_norm_stderr,none': 0.033458517029435815},
#   'gsm8k': {'alias': 'gsm8k',
#    'exact_match,strict-match': 0.045,
#    'exact_match_stderr,strict-match': 0.014695399751940959,
#    'exact_match,flexible-extract': 0.06,
#    'exact_match_stderr,flexible-extract': 0.01683499585468128},
#   'medmcqa': {'alias': 'medmcqa',
#    'acc,none': 0.355,
#    'acc_stderr,none': 0.033920910080708536,
#    'acc_norm,none': 0.355,
#    'acc_norm_stderr,none': 0.033920910080708536},
#   'mmlu': {'acc,none': 0.3202657083741697,
#    'acc_stderr,none': 0.004835622492408295,
#    'alias': 'mmlu'},
#   'mmlu_humanities': {'acc,none': 0.33717834960070986,
#    'acc_stderr,none': 0.009900750074751991,
#    'alias': ' - humanities'},
#   'mmlu_formal_logic': {'alias': '  - formal_logic',
#    'acc,none': 0.19047619047619047,
#    'acc_stderr,none': 0.03512207412302055},
#   'mmlu_high_school_european_history': {'alias': '  - high_school_european_history',
#    'acc,none': 0.45454545454545453,
#    'acc_stderr,none': 0.038881769216741004},
#   'mmlu_high_school_us_history': {'alias': '  - high_school_us_history',
#    'acc,none': 0.36,
#    'acc_stderr,none': 0.03402629784040017},
#   'mmlu_high_school_world_history': {'alias': '  - high_school_world_history',
#    'acc,none': 0.375,
#    'acc_stderr,none': 0.03431856376795913},
#   'mmlu_international_law': {'alias': '  - international_law',
#    'acc,none': 0.3884297520661157,
#    'acc_stderr,none': 0.04449270350068382},
#   'mmlu_jurisprudence': {'alias': '  - jurisprudence',
#    'acc,none': 0.39814814814814814,
#    'acc_stderr,none': 0.04732332615978814},
#   'mmlu_logical_fallacies': {'alias': '  - logical_fallacies',
#    'acc,none': 0.31901840490797545,
#    'acc_stderr,none': 0.03661997551073836},
#   'mmlu_moral_disputes': {'alias': '  - moral_disputes',
#    'acc,none': 0.335,
#    'acc_stderr,none': 0.033458517029435815},
#   'mmlu_moral_scenarios': {'alias': '  - moral_scenarios',
#    'acc,none': 0.245,
#    'acc_stderr,none': 0.03048807329211419},
#   'mmlu_philosophy': {'alias': '  - philosophy',
#    'acc,none': 0.35,
#    'acc_stderr,none': 0.033811478530256706},
#   'mmlu_prehistory': {'alias': '  - prehistory',
#    'acc,none': 0.35,
#    'acc_stderr,none': 0.033811478530256706},
#   'mmlu_professional_law': {'alias': '  - professional_law',
#    'acc,none': 0.28,
#    'acc_stderr,none': 0.03182868716477582},
#   'mmlu_world_religions': {'alias': '  - world_religions',
#    'acc,none': 0.3508771929824561,
#    'acc_stderr,none': 0.03660298834049163},
#   'mmlu_other': {'acc,none': 0.32633053221288516,
#    'acc_stderr,none': 0.010081715957815835,
#    'alias': ' - other'},
#   'mmlu_business_ethics': {'alias': '  - business_ethics',
#    'acc,none': 0.33,
#    'acc_stderr,none': 0.04725815626252604},
#   'mmlu_clinical_knowledge': {'alias': '  - clinical_knowledge',
#    'acc,none': 0.255,
#    'acc_stderr,none': 0.03089738243291862},
#   'mmlu_college_medicine': {'alias': '  - college_medicine',
#    'acc,none': 0.24855491329479767,
#    'acc_stderr,none': 0.03295304696818318},
#   'mmlu_global_facts': {'alias': '  - global_facts',
#    'acc,none': 0.31,
#    'acc_stderr,none': 0.04648231987117316},
#   'mmlu_human_aging': {'alias': '  - human_aging',
#    'acc,none': 0.29,
#    'acc_stderr,none': 0.03216633903375033},
#   'mmlu_management': {'alias': '  - management',
#    'acc,none': 0.3883495145631068,
#    'acc_stderr,none': 0.0482572933735639},
#   'mmlu_marketing': {'alias': '  - marketing',
#    'acc,none': 0.43,
#    'acc_stderr,none': 0.03509498954918328},
#   'mmlu_medical_genetics': {'alias': '  - medical_genetics',
#    'acc,none': 0.37,
#    'acc_stderr,none': 0.048523658709391},
#   'mmlu_miscellaneous': {'alias': '  - miscellaneous',
#    'acc,none': 0.38,
#    'acc_stderr,none': 0.03440813273035819},
#   'mmlu_nutrition': {'alias': '  - nutrition',
#    'acc,none': 0.385,
#    'acc_stderr,none': 0.03449382728261698},
#   'mmlu_professional_accounting': {'alias': '  - professional_accounting',
#    'acc,none': 0.3,
#    'acc_stderr,none': 0.03248501780682212},
#   'mmlu_professional_medicine': {'alias': '  - professional_medicine',
#    'acc,none': 0.26,
#    'acc_stderr,none': 0.031093957143700272},
#   'mmlu_virology': {'alias': '  - virology',
#    'acc,none': 0.3313253012048193,
#    'acc_stderr,none': 0.03664314777288085},
#   'mmlu_social_sciences': {'acc,none': 0.323069403714565,
#    'acc_stderr,none': 0.01027536255407188,
#    'alias': ' - social sciences'},
#   'mmlu_econometrics': {'alias': '  - econometrics',
#    'acc,none': 0.22807017543859648,
#    'acc_stderr,none': 0.03947152782669415},
#   'mmlu_high_school_geography': {'alias': '  - high_school_geography',
#    'acc,none': 0.29797979797979796,
#    'acc_stderr,none': 0.032586303838365555},
#   'mmlu_high_school_government_and_politics': {'alias': '  - high_school_government_and_politics',
#    'acc,none': 0.31088082901554404,
#    'acc_stderr,none': 0.03340361906276586},
#   'mmlu_high_school_macroeconomics': {'alias': '  - high_school_macroeconomics',
#    'acc,none': 0.265,
#    'acc_stderr,none': 0.03128528159088722},
#   'mmlu_high_school_microeconomics': {'alias': '  - high_school_microeconomics',
#    'acc,none': 0.285,
#    'acc_stderr,none': 0.03199992148231577},
#   'mmlu_high_school_psychology': {'alias': '  - high_school_psychology',
#    'acc,none': 0.375,
#    'acc_stderr,none': 0.03431856376795913},
#   'mmlu_human_sexuality': {'alias': '  - human_sexuality',
#    'acc,none': 0.2595419847328244,
#    'acc_stderr,none': 0.03844876139785271},
#   'mmlu_professional_psychology': {'alias': '  - professional_psychology',
#    'acc,none': 0.37,
#    'acc_stderr,none': 0.034225089976793285},
#   'mmlu_public_relations': {'alias': '  - public_relations',
#    'acc,none': 0.2818181818181818,
#    'acc_stderr,none': 0.043091187099464585},
#   'mmlu_security_studies': {'alias': '  - security_studies',
#    'acc,none': 0.305,
#    'acc_stderr,none': 0.032637417254205714},
#   'mmlu_sociology': {'alias': '  - sociology',
#    'acc,none': 0.415,
#    'acc_stderr,none': 0.0349281387189735},
#   'mmlu_us_foreign_policy': {'alias': '  - us_foreign_policy',
#    'acc,none': 0.48,
#    'acc_stderr,none': 0.050211673156867795},
#   'mmlu_stem': {'acc,none': 0.2995257205399489,
#    'acc_stderr,none': 0.008675602104901056,
#    'alias': ' - stem'},
#   'mmlu_abstract_algebra': {'alias': '  - abstract_algebra',
#    'acc,none': 0.31,
#    'acc_stderr,none': 0.04648231987117316},
#   'mmlu_anatomy': {'alias': '  - anatomy',
#    'acc,none': 0.4222222222222222,
#    'acc_stderr,none': 0.042667634040995814},
#   'mmlu_astronomy': {'alias': '  - astronomy',
#    'acc,none': 0.40131578947368424,
#    'acc_stderr,none': 0.039889037033362836},
#   'mmlu_college_biology': {'alias': '  - college_biology',
#    'acc,none': 0.3263888888888889,
#    'acc_stderr,none': 0.03921067198982266},
#   'mmlu_college_chemistry': {'alias': '  - college_chemistry',
#    'acc,none': 0.3,
#    'acc_stderr,none': 0.046056618647183814},
#   'mmlu_college_computer_science': {'alias': '  - college_computer_science',
#    'acc,none': 0.34,
#    'acc_stderr,none': 0.04760952285695235},
#   'mmlu_college_mathematics': {'alias': '  - college_mathematics',
#    'acc,none': 0.32,
#    'acc_stderr,none': 0.046882617226215034},
#   'mmlu_college_physics': {'alias': '  - college_physics',
#    'acc,none': 0.19607843137254902,
#    'acc_stderr,none': 0.039505818611799616},
#   'mmlu_computer_security': {'alias': '  - computer_security',
#    'acc,none': 0.39,
#    'acc_stderr,none': 0.04902071300001975},
#   'mmlu_conceptual_physics': {'alias': '  - conceptual_physics',
#    'acc,none': 0.375,
#    'acc_stderr,none': 0.03431856376795913},
#   'mmlu_electrical_engineering': {'alias': '  - electrical_engineering',
#    'acc,none': 0.31724137931034485,
#    'acc_stderr,none': 0.038783523721386215},
#   'mmlu_elementary_mathematics': {'alias': '  - elementary_mathematics',
#    'acc,none': 0.225,
#    'acc_stderr,none': 0.02960162633044061},
#   'mmlu_high_school_biology': {'alias': '  - high_school_biology',
#    'acc,none': 0.305,
#    'acc_stderr,none': 0.032637417254205714},
#   'mmlu_high_school_chemistry': {'alias': '  - high_school_chemistry',
#    'acc,none': 0.31,
#    'acc_stderr,none': 0.032785276754349606},
#   'mmlu_high_school_computer_science': {'alias': '  - high_school_computer_science',
#    'acc,none': 0.31,
#    'acc_stderr,none': 0.046482319871173156},
#   'mmlu_high_school_mathematics': {'alias': '  - high_school_mathematics',
#    'acc,none': 0.24,
#    'acc_stderr,none': 0.03027512038907304},
#   'mmlu_high_school_physics': {'alias': '  - high_school_physics',
#    'acc,none': 0.271523178807947,
#    'acc_stderr,none': 0.03631329803969653},
#   'mmlu_high_school_statistics': {'alias': '  - high_school_statistics',
#    'acc,none': 0.15,
#    'acc_stderr,none': 0.025312121949531266},
#   'mmlu_machine_learning': {'alias': '  - machine_learning',
#    'acc,none': 0.2767857142857143,
#    'acc_stderr,none': 0.042466243366976256}}}
